# %% [markdown]
# This tool looks at a portal's items and gets descriptions of the items.

# %%
from IPython.display import display
from arcgis.gis import GIS
#import os
import requests
from getpass import getpass
from datetime import datetime

# %% [markdown]
# In the cell below, you will connect to your Portal for ArcGIS.
#
# <li> portal = the URL of the Portal "https://servername.domain.com/webadaptor"
# <li> username = an admin's user name
# <li> password = the password for that user

# %%
portal = "https://wdcdefense.esri.com/portal"

# %%
username = "jfwdcdefense"

# %%
password = getpass()
gis = GIS(portal, username, password, verify_cert=True)
# Out:
# ········

# %% [markdown]
# Gets usernames.

# %%
gisusers = gis.users.search()
#gisusers

# %% [markdown]
# If you do not want users to have their content listed, then you can manual write their username in the list below.

# %%
ignore_list = ['system_publisher', 'esri_nav', 'esri_livingatlas', 
               'esri_boundaries', 'esri_demographics','admin']

# %%
#temp_user_list = ['adrain', 'james_jones', 'jfwdcdefense']
#temp_user_list = ['john6807@AVWORLD']

# %% [markdown]
# In the cell below, items in the featured gallery will listed and then items in the web maps will also be listed.

# %%
source_items_by_id = {}
contains_list = 'Could not access any server machines. Please contact your system administrator.'
webappbuilder = ':3344/webappbuilder'
package = 'package'
data = 'data'


for user in gisusers:
    # time for eaxh user iteration
    startTime = datetime.now()
    
    if not user.username in ignore_list:  # ignore any 'system' Portal users
    #if user.username in temp_user_list:  # ignore any 'system' Portal users
        print ("===========================User================================")
        print("Collecting items for {}...".format(user.username))
        user_content = user.items(max_items=100000)
        
        # item ids from root folder first
        for item in user_content:
            #Do not try and ping None item.URL
            
            if (item.url is not None and webappbuilder not in item.url and package not in item.url and data not in item.url):
            #if (item.url is not None):
                try:
                    r = requests.get(item.url)
                    if contains_list in r.text:
                        #r = requests.get(item.url)
                        print("User = " +user.username)
                        print("Folder = root")
                        print("Item = "+item.title)
                        print("Type = " +item.type)
                        print("URL = " +item.url)
                        print ("Item URL = " + "https://wdcdefense.esri.com/portal/home/item.html?id=" + item.id)
                        print ("Server up, Service Not")
                        print("-------------------------Item-------------------------------")
                        continue
                                    #check for URLs that do not exist    
                except requests.exceptions.RequestException as e:  
                    print (e)
                    if e:
                        print("User = " +user.username)
                        print("Folder = root")
                        print("Item = "+item.title)
                        print("Type = " +item.type)
                        print("URL = " +item.url)
                        print ("Item URL = " + "https://wdcdefense.esri.com/portal/home/item.html?id=" + item.id)
                        print ('This is a bad url')
                        print("-------------------------Item-------------------------------")
                        #continue
                        pass
                    
                else:
                    #print ("Root")
                    pass

                        

                        
                #item ids from folders next
        folders = user.folders
        for folder in folders:
            folder_items = user.items(folder=folder['title'], max_items=10000)
            folder_title = folder['title']
            #if (item.url is not None and webappbuilder not in item.url and package not in item.url and data not in item.url):

            for item in folder_items:
                #source_items_by_id[item.itemid] = item
                if (item.url is not None and webappbuilder not in item.url and package not in item.url and data not in item.url):
                    try:
                        r = requests.get(item.url)
                        if contains_list in r.text:
                            #r = requests.get(item.url)
                            print("User = " +user.username)
                            print("Folder = "+folder_title)
                            print("Item = "+item.title)
                            print("Type = " +item.type)
                            print("URL = " +item.url)
                            print ("Item URL = " + "https://wdcdefense.esri.com/portal/home/item.html?id=" + item.id)
                            print (("Status Code = ") +str(r.status_code))
                            print ("Server up, Service Not")
                            print("-------------------------Item-------------------------------")
                            continue

                    except requests.exceptions.RequestException as e: 
                        print (e)
                        if e:
                            print("User = " +user.username)
                            print("Folder = "+folder_title)
                            print("Item = "+item.title)
                            print("Type = " +item.type)
                            print("URL = " +item.url)
                            print ("Item URL = " + "https://wdcdefense.esri.com/portal/home/item.html?id=" + item.id)
                            print ("This is a bad url")
                            print("-------------------------Item-------------------------------")
                            #continue  else:
                            #print("in folder " +folder_title)
                            pass

                    else:
                        #print ("in folder " +folder_title)
                        #print ("Folder / Item = "+folder_title + item.title)
                        continue
        
        print ("Completed bad item search for {}...".format(user.username))
        print (print("Time taken: " + str(datetime.now() - startTime)))
        print ("===========================User================================")
# Out:
# ===========================User================================
# Collecting items for AAwdcdefense...
# Completed bad item search for AAwdcdefense...
# Time taken: 0:00:10.086021
# None
# ===========================User================================
# ===========================User================================
# Collecting items for adrain...
# User = adrain
# Folder = root
# Item = SpireDataExampleSTBDS
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/SpireDataExampleSTBDS/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=0b15a2d38fb54d17a57281e442ce6d73
# Server up, Service Not
# -------------------------Item-------------------------------
# User = adrain
# Folder = root
# Item = SpireDataExampleSTBDS
# Type = Feature Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/SpireDataExampleSTBDS/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=f0af9b1f1f60458ab99d7c16fa56ca61
# Server up, Service Not
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='ec2-50-16-164-129.compute-1.amazonaws.com', port=443): Max retries exceeded with url: /ags/rest/services/NationalIntelligence/DistanceFromTrailsMosaic/ImageServer (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B29370320>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = adrain
# Folder = test
# Item = Distance From Trails
# Type = Image Service
# URL = https://ec2-50-16-164-129.compute-1.amazonaws.com/ags/rest/services/NationalIntelligence/DistanceFromTrailsMosaic/ImageServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=25d1fc84246b4f92913d818c35658eaf
# This is a bad url
# -------------------------Item-------------------------------
# Completed bad item search for adrain...
# Time taken: 0:00:50.450579
# None
# ===========================User================================
# ===========================User================================
# Collecting items for agwdcdefense...
# Completed bad item search for agwdcdefense...
# Time taken: 0:00:00.508770
# None
# ===========================User================================
# ===========================User================================
# Collecting items for analyst...
# Completed bad item search for analyst...
# Time taken: 0:00:05.068208
# None
# ===========================User================================
# ===========================User================================
# Collecting items for andrew_king...
# Completed bad item search for andrew_king...
# Time taken: 0:00:02.460981
# None
# ===========================User================================
# ===========================User================================
# Collecting items for anwdcdefense...
# Completed bad item search for anwdcdefense...
# Time taken: 0:00:01.068963
# None
# ===========================User================================
# ===========================User================================
# Collecting items for asmialek...
# Completed bad item search for asmialek...
# Time taken: 0:00:01.157940
# None
# ===========================User================================
# ===========================User================================
# Collecting items for blehman...
# Completed bad item search for blehman...
# Time taken: 0:00:00.299079
# None
# ===========================User================================
# ===========================User================================
# Collecting items for ccdefenseaws...
# Completed bad item search for ccdefenseaws...
# Time taken: 0:00:00.302485
# None
# ===========================User================================
# ===========================User================================
# Collecting items for cmcguirewdc...
# Completed bad item search for cmcguirewdc...
# Time taken: 0:00:22.012951
# None
# ===========================User================================
# ===========================User================================
# Collecting items for cmenzel...
# Completed bad item search for cmenzel...
# Time taken: 0:00:00.279534
# None
# ===========================User================================
# ===========================User================================
# Collecting items for csdefenseaws...
# Completed bad item search for csdefenseaws...
# Time taken: 0:00:00.290028
# None
# ===========================User================================
# ===========================User================================
# Collecting items for dadefenseaws...
# Completed bad item search for dadefenseaws...
# Time taken: 0:00:01.554261
# None
# ===========================User================================
# ===========================User================================
# Collecting items for dewdcdefense...
# Completed bad item search for dewdcdefense...
# Time taken: 0:00:00.286306
# None
# ===========================User================================
# ===========================User================================
# Collecting items for gscoffield...
# Completed bad item search for gscoffield...
# Time taken: 0:00:09.832690
# None
# ===========================User================================
# ===========================User================================
# Collecting items for james_jones...
# Completed bad item search for james_jones...
# Time taken: 0:01:40.007338
# None
# ===========================User================================
# ===========================User================================
# Collecting items for jamon_johnson...
# Completed bad item search for jamon_johnson...
# Time taken: 0:00:00.315871
# None
# ===========================User================================
# ===========================User================================
# Collecting items for jbauer...
# User = jbauer
# Folder = root
# Item = WorldAirfields
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/USAF/WorldAirfields/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=de11bdd252924e0f8b36af6268d4d49b
# Server up, Service Not
# -------------------------Item-------------------------------
# User = jbauer
# Folder = root
# Item = BauerTest
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/USAF/BauerTest/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=354b88bf2e31478eab41b2cdad79dad4
# Server up, Service Not
# -------------------------Item-------------------------------
# User = jbauer
# Folder = root
# Item = WorldAirfields
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/USAF/WorldAirfields/MapServer/
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=56d9b0a9d322455d977a6fc60d93c6a5
# Server up, Service Not
# -------------------------Item-------------------------------
# User = jbauer
# Folder = WorldAirfields
# Item = WorldAirfields
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/USAF/WorldAirfields/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=4c2300794e984248a60741810116c000
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# Completed bad item search for jbauer...
# Time taken: 0:00:17.199559
# None
# ===========================User================================
# ===========================User================================
# Collecting items for jddefenseaws...
# Completed bad item search for jddefenseaws...
# Time taken: 0:00:00.301154
# None
# ===========================User================================
# ===========================User================================
# Collecting items for jdwdcdefense...
# Completed bad item search for jdwdcdefense...
# Time taken: 0:00:03.562880
# None
# ===========================User================================
# ===========================User================================
# Collecting items for jfraleywdc...
# Completed bad item search for jfraleywdc...
# Time taken: 0:00:00.635454
# None
# ===========================User================================
# ===========================User================================
# Collecting items for jfwdcdefense...
# User = jfwdcdefense
# Folder = AirC2
# Item = AirC2_Military_Air_Tracks
# Type = Feature Service
# URL = https://wdcdefense.esri.com/server/rest/services/AirC2/Military_Air_Tracks/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=1a039b8dc9d3462b9cec955d99686f0e
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = jfwdcdefense
# Folder = AirC2
# Item = AirC2_Military_Air_Tracks-nw
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/AirC2/Military_Air_Tracks/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=578ee1f151904f8c99178c924af52da9
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = jfwdcdefense
# Folder = Insights
# Item = ASAM1978to2016
# Type = Feature Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/ASAM1978to2016/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=83d197a3290f4240a956be0cc8c6d2e4
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='wdcintelgis.esri.com', port=443): Max retries exceeded with url: /arcgis/rest/services/LocateXT_Services/LocateXT_maritime_polygon/GPServer (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B294DE198>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = jfwdcdefense
# Folder = LocateXT
# Item = LocateXT Polygon Extraction Tool
# Type = Geoprocessing Service
# URL = https://wdcintelgis.esri.com/arcgis/rest/services/LocateXT_Services/LocateXT_maritime_polygon/GPServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=3a39bff8ecc54dfe92ef187ab5635e02
# This is a bad url
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='gis.charttools.noaa.gov', port=443): Max retries exceeded with url: /arcgis/rest/services/MCS/ENCOnline/MapServer/exts/Maritime%20Chart%20Server/MapServer (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B294BEF60>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = jfwdcdefense
# Folder = Maritime Domain Awareness
# Item = Maritime Chart
# Type = Map Service
# URL = https://gis.charttools.noaa.gov/arcgis/rest/services/MCS/ENCOnline/MapServer/exts/Maritime%20Chart%20Server/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=bbfaab657f164a7481cb8eb29cfd2726
# This is a bad url
# -------------------------Item-------------------------------
# User = jfwdcdefense
# Folder = TSMO
# Item = TSMO_Historic_Count
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/TSMO_Historic_Count/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=2bea1840873d40f19111865741302541
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = jfwdcdefense
# Folder = TSMO
# Item = TSMO_Historic_Accuracy
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/TSMO_Historic_Accuracy/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=bb03f510b6da431abcf5f32314035427
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = jfwdcdefense
# Folder = TSMO
# Item = TSMO_Historic_Quality
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/TSMO_Historic_Quality/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=4fdbc601acad4d779fdf44de5ef68ee7
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# HTTPConnectionPool(host='jfry2.esri.com', port=3344): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000023B2FC88E48>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))
# User = jfwdcdefense
# Folder = Web App Builder
# Item = Web App Builder Dev Jfry2
# Type = Web Mapping Application
# URL = http://jfry2.esri.com:3344
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=9e867cfe023d482ead50bdd9ec55089a
# This is a bad url
# -------------------------Item-------------------------------
# Completed bad item search for jfwdcdefense...
# Time taken: 0:06:09.635234
# None
# ===========================User================================
# ===========================User================================
# Collecting items for jhaefner_defense...
# Completed bad item search for jhaefner_defense...
# Time taken: 0:00:01.156863
# None
# ===========================User================================
# ===========================User================================
# Collecting items for jimbennett...
# Completed bad item search for jimbennett...
# Time taken: 0:00:04.666803
# None
# ===========================User================================
# ===========================User================================
# Collecting items for jkwdcdefense...
# Completed bad item search for jkwdcdefense...
# Time taken: 0:00:04.471074
# None
# ===========================User================================
# ===========================User================================
# Collecting items for jmwdcdefense...
# Completed bad item search for jmwdcdefense...
# Time taken: 0:00:00.327408
# None
# ===========================User================================
# ===========================User================================
# Collecting items for joebayles...
# Completed bad item search for joebayles...
# Time taken: 0:00:10.253615
# None
# ===========================User================================
# ===========================User================================
# Collecting items for jsullivan_defense...
# Completed bad item search for jsullivan_defense...
# Time taken: 0:00:11.787072
# None
# ===========================User================================
# ===========================User================================
# Collecting items for jsullivanwdc...
# Completed bad item search for jsullivanwdc...
# Time taken: 0:00:48.407332
# None
# ===========================User================================
# ===========================User================================
# Collecting items for jswdcdefense...
# Completed bad item search for jswdcdefense...
# Time taken: 0:00:01.258268
# None
# ===========================User================================
# ===========================User================================
# Collecting items for jwilsonwdc...
# Completed bad item search for jwilsonwdc...
# Time taken: 0:00:00.282515
# None
# ===========================User================================
# ===========================User================================
# Collecting items for kenyon...
# Completed bad item search for kenyon...
# Time taken: 0:00:01.157592
# None
# ===========================User================================
# ===========================User================================
# Collecting items for klevywdc...
# Completed bad item search for klevywdc...
# Time taken: 0:00:40.428706
# None
# ===========================User================================
# ===========================User================================
# Collecting items for kmazariwdc...
# Completed bad item search for kmazariwdc...
# Time taken: 0:00:00.326025
# None
# ===========================User================================
# ===========================User================================
# Collecting items for KMitchell_Defense...
# Completed bad item search for KMitchell_Defense...
# Time taken: 0:00:00.280412
# None
# ===========================User================================
# ===========================User================================
# Collecting items for krobinson...
# Completed bad item search for krobinson...
# Time taken: 0:00:02.896526
# None
# ===========================User================================
# ===========================User================================
# Collecting items for KTalbot_Defense...
# Completed bad item search for KTalbot_Defense...
# Time taken: 0:00:01.962153
# None
# ===========================User================================
# ===========================User================================
# Collecting items for lzhang...
# Completed bad item search for lzhang...
# Time taken: 0:00:01.186283
# None
# ===========================User================================
# ===========================User================================
# Collecting items for lzwdcdefense...
# Completed bad item search for lzwdcdefense...
# Time taken: 0:00:01.172183
# None
# ===========================User================================
# ===========================User================================
# Collecting items for mkwdcdefense...
# Completed bad item search for mkwdcdefense...
# Time taken: 0:00:01.131524
# None
# ===========================User================================
# ===========================User================================
# Collecting items for mmdefenseaws...
# Completed bad item search for mmdefenseaws...
# Time taken: 0:00:00.305723
# None
# ===========================User================================
# ===========================User================================
# Collecting items for mpdefenseaws...
# Completed bad item search for mpdefenseaws...
# Time taken: 0:00:01.160721
# None
# ===========================User================================
# ===========================User================================
# Collecting items for mreynolds...
# Completed bad item search for mreynolds...
# Time taken: 0:00:00.308589
# None
# ===========================User================================
# ===========================User================================
# Collecting items for mwdefenseaws...
# Completed bad item search for mwdefenseaws...
# Time taken: 0:00:13.727091
# None
# ===========================User================================
# ===========================User================================
# Collecting items for nswdcdefense...
# Completed bad item search for nswdcdefense...
# Time taken: 0:00:00.302573
# None
# ===========================User================================
# ===========================User================================
# Collecting items for nwwdcdefense...
# Completed bad item search for nwwdcdefense...
# Time taken: 0:00:00.310906
# None
# ===========================User================================
# ===========================User================================
# Collecting items for pfdefenseaws...
# Completed bad item search for pfdefenseaws...
# Time taken: 0:00:03.645186
# None
# ===========================User================================
# ===========================User================================
# Collecting items for pfwdcdefense...
# Completed bad item search for pfwdcdefense...
# Time taken: 0:00:00.293087
# None
# ===========================User================================
# ===========================User================================
# Collecting items for phornstein...
# User = phornstein
# Folder = root
# Item = Sample_Trajectory
# Type = Feature Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/Sample_Trajectory/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=32d194b6619846ccb5cbe94c6f6ad766
# Server up, Service Not
# -------------------------Item-------------------------------
# Completed bad item search for phornstein...
# Time taken: 0:01:31.341890
# None
# ===========================User================================
# ===========================User================================
# Collecting items for pobrien...
# Completed bad item search for pobrien...
# Time taken: 0:00:01.147884
# None
# ===========================User================================
# ===========================User================================
# Collecting items for psdefenseaws...
# Completed bad item search for psdefenseaws...
# Time taken: 0:00:00.289345
# None
# ===========================User================================
# ===========================User================================
# Collecting items for pshowalterwdc...
# Completed bad item search for pshowalterwdc...
# Time taken: 0:00:00.329800
# None
# ===========================User================================
# ===========================User================================
# Collecting items for rbernstein...
# Completed bad item search for rbernstein...
# Time taken: 0:00:17.092771
# None
# ===========================User================================
# ===========================User================================
# Collecting items for scdefenseaws...
# User = scdefenseaws
# Folder = Cheyenne
# Item = Compound_Analysis_WTL2
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/Compound_Analysis_WTL2/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=b057e144728546baa4f8eca41d615193
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = scdefenseaws
# Folder = Cheyenne
# Item = LOAC Considerations Buffer Zone
# Type = Feature Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/Buffer_of_LOAC_Considerations1/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=7d51224d84ed41e793dd5b34212a5023
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = scdefenseaws
# Folder = Cheyenne
# Item = Compound_Analysis_WTL1
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/Compound_Analysis_WTL1/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=4417bad277c442ce8245224ce453f10a
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = scdefenseaws
# Folder = J33
# Item = Military_Overlay_2525B_Change_2
# Type = Feature Service
# URL = https://wdcdefense.esri.com/server/rest/services/Military_Overlay_2525B_Change_2/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=1ecabf0fce9744f6a274ed82770c13b7
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = scdefenseaws
# Folder = Military
# Item = OSINT_Reports
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Military/OSINT_Reports/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=f078a78838dd4174a695afcbc8bd2bef
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = scdefenseaws
# Folder = Military
# Item = OSINT_Reports
# Type = Feature Service
# URL = https://wdcdefense.esri.com/server/rest/services/Military/OSINT_Reports/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=95f11fab1e904575a9cc8d8790a78b29
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = scdefenseaws
# Folder = Operational Intelligence
# Item = MetroPCS Cell Sites (FL)
# Type = Feature Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/MetroPCS_Cell_Sites_(FL)/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=358a64cebe0b493bb70b1944083f4f93
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# Completed bad item search for scdefenseaws...
# Time taken: 0:01:18.568686
# None
# ===========================User================================
# ===========================User================================
# Collecting items for skusano...
# Completed bad item search for skusano...
# Time taken: 0:00:18.396946
# None
# ===========================User================================
# ===========================User================================
# Collecting items for srucker...
# Completed bad item search for srucker...
# Time taken: 0:00:01.175679
# None
# ===========================User================================
# ===========================User================================
# Collecting items for t_murphy...
# Completed bad item search for t_murphy...
# Time taken: 0:00:01.152618
# None
# ===========================User================================
# ===========================User================================
# Collecting items for tcorbett...
# Completed bad item search for tcorbett...
# Time taken: 0:00:00.329539
# None
# ===========================User================================
# ===========================User================================
# Collecting items for tdepuytwdc...
# Completed bad item search for tdepuytwdc...
# Time taken: 0:00:00.357873
# None
# ===========================User================================
# ===========================User================================
# Collecting items for thomassmedley...
# Completed bad item search for thomassmedley...
# Time taken: 0:00:07.214357
# None
# ===========================User================================
# ===========================User================================
# Collecting items for toakswdc...
# Completed bad item search for toakswdc...
# Time taken: 0:00:01.141037
# None
# ===========================User================================
# ===========================User================================
# Collecting items for tquink...
# User = tquink
# Folder = root
# Item = watersheds
# Type = Feature Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/watersheds/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=d26f4f1fa1fe4b6faaa552429aa67532
# Server up, Service Not
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='wdcintelgis.esri.com', port=443): Max retries exceeded with url: /arcgis/rest/services/LocateXT_geocoord_extraction/GPServer/LocateXT_geocoord_extraction (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B29355208>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = tquink
# Folder = root
# Item = LocateXT_geocoord_extraction
# Type = Geoprocessing Service
# URL = https://wdcintelgis.esri.com/arcgis/rest/services/LocateXT_geocoord_extraction/GPServer/LocateXT_geocoord_extraction
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=2b525f260ab843fda8344da36e238124
# This is a bad url
# -------------------------Item-------------------------------
# User = tquink
# Folder = AirC2
# Item = AirC2_ElevationBoundary
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/AirC2/AirC2_ElevationBoundary/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=05045ce583fe4c2b8a465db18f0c6977
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = AirC2
# Item = AirC2_ElevationBoundary
# Type = Feature Service
# URL = https://wdcdefense.esri.com/server/rest/services/AirC2/AirC2_ElevationBoundary/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=5c0dec2aaf8e4561a49d072bc7909331
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='ec2-50-16-164-129.compute-1.amazonaws.com', port=443): Max retries exceeded with url: /ags/rest/services/NationalIntelligence/BasicDiversity/MapServer (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B2FDB1470>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = tquink
# Folder = DemoIntelligence
# Item = Basic Diversity Demographics
# Type = Map Service
# URL = https://ec2-50-16-164-129.compute-1.amazonaws.com/ags/rest/services/NationalIntelligence/BasicDiversity/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=02ac8e76460448f88d5d5ff643bd4a34
# This is a bad url
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='ec2-50-16-164-129.compute-1.amazonaws.com', port=443): Max retries exceeded with url: /ags/rest/services/NationalIntelligence/ClusterAnalysis/GPServer (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B30F682E8>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = tquink
# Folder = DemoIntelligence
# Item = Cluster Analysis
# Type = Geoprocessing Service
# URL = https://ec2-50-16-164-129.compute-1.amazonaws.com/ags/rest/services/NationalIntelligence/ClusterAnalysis/GPServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=e3373ca97dc045f08b9c49c4408837ff
# This is a bad url
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='ec2-50-16-164-129.compute-1.amazonaws.com', port=443): Max retries exceeded with url: /ags/rest/services/NationalIntelligence/CountryBoundaries/MapServer (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B30F68128>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = tquink
# Folder = DemoIntelligence
# Item = Country Boundaries
# Type = Map Service
# URL = https://ec2-50-16-164-129.compute-1.amazonaws.com/ags/rest/services/NationalIntelligence/CountryBoundaries/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=e230b0804838428280e75e00f57703e0
# This is a bad url
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='ec2-50-16-164-129.compute-1.amazonaws.com', port=443): Max retries exceeded with url: /ags/rest/services/NationalIntelligence/CountryBoundaries/ImageServer (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B2FDC5DA0>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = tquink
# Folder = DemoIntelligence
# Item = Country Boundaries Raster
# Type = Image Service
# URL = https://ec2-50-16-164-129.compute-1.amazonaws.com/ags/rest/services/NationalIntelligence/CountryBoundaries/ImageServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=8380a841989e481db4a84bf9461330d3
# This is a bad url
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='ec2-50-16-164-129.compute-1.amazonaws.com', port=443): Max retries exceeded with url: /ags/rest/services/NationalIntelligence/DistanceFromAllWeatherRoadsMosaic/ImageServer (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B2FDC5DA0>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = tquink
# Folder = DemoIntelligence
# Item = Distance From All Weather Roads
# Type = Image Service
# URL = https://ec2-50-16-164-129.compute-1.amazonaws.com/ags/rest/services/NationalIntelligence/DistanceFromAllWeatherRoadsMosaic/ImageServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=5da4eee6ad7c4b8686a846edc1d00633
# This is a bad url
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='ec2-50-16-164-129.compute-1.amazonaws.com', port=443): Max retries exceeded with url: /ags/rest/services/NationalIntelligence/DistanceFromFairWeatherRoadsMosaic/ImageServer (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B30F68BE0>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = tquink
# Folder = DemoIntelligence
# Item = Distance From Fair Weather Roads
# Type = Image Service
# URL = https://ec2-50-16-164-129.compute-1.amazonaws.com/ags/rest/services/NationalIntelligence/DistanceFromFairWeatherRoadsMosaic/ImageServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=143e8f14b0874efc96687d38df945201
# This is a bad url
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='ec2-50-16-164-129.compute-1.amazonaws.com', port=443): Max retries exceeded with url: /ags/rest/services/NationalIntelligence/DistanceFromForestEdgeMosaic/ImageServer (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B2FDB1C50>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = tquink
# Folder = DemoIntelligence
# Item = Distance From Forest Edge
# Type = Image Service
# URL = https://ec2-50-16-164-129.compute-1.amazonaws.com/ags/rest/services/NationalIntelligence/DistanceFromForestEdgeMosaic/ImageServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=4e692d7a0a8d400b8efec143482356b5
# This is a bad url
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='ec2-50-16-164-129.compute-1.amazonaws.com', port=443): Max retries exceeded with url: /ags/rest/services/NationalIntelligence/DistanceFromOceanMosaic/ImageServer (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B2FDB1550>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = tquink
# Folder = DemoIntelligence
# Item = Distance From Ocean
# Type = Image Service
# URL = https://ec2-50-16-164-129.compute-1.amazonaws.com/ags/rest/services/NationalIntelligence/DistanceFromOceanMosaic/ImageServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=08c88a27b1464ebf8b44c4294d77aed2
# This is a bad url
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='ec2-50-16-164-129.compute-1.amazonaws.com', port=443): Max retries exceeded with url: /ags/rest/services/NationalIntelligence/DistanceFromWaterSourcesMosaic/ImageServer (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B2FDD26A0>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = tquink
# Folder = DemoIntelligence
# Item = Distance From Water Sources
# Type = Image Service
# URL = https://ec2-50-16-164-129.compute-1.amazonaws.com/ags/rest/services/NationalIntelligence/DistanceFromWaterSourcesMosaic/ImageServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=c606ddff090241b084488fc12ccc1e54
# This is a bad url
# -------------------------Item-------------------------------
# User = tquink
# Folder = DemoIntelligence
# Item = DistrictBoundaries
# Type = Feature Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/DistrictBoundaries/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=5b0542a861164e8e8eada292ae8cae6c
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='ec2-50-16-164-129.compute-1.amazonaws.com', port=443): Max retries exceeded with url: /ags/rest/services/Hosted/DistrictBoundaries/FeatureServer (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B2FE32208>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = tquink
# Folder = DemoIntelligence
# Item = DistrictBoundaries
# Type = Feature Service
# URL = https://ec2-50-16-164-129.compute-1.amazonaws.com/ags/rest/services/Hosted/DistrictBoundaries/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=cf9f63e80b864f8db69c43a037bb297d
# This is a bad url
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='ec2-50-16-164-129.compute-1.amazonaws.com', port=443): Max retries exceeded with url: /ags/rest/services/NationalIntelligence/Elevation/ImageServer (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B30F61748>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = tquink
# Folder = DemoIntelligence
# Item = Elevation
# Type = Image Service
# URL = https://ec2-50-16-164-129.compute-1.amazonaws.com/ags/rest/services/NationalIntelligence/Elevation/ImageServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=f3c089a99d504ca592fe4f74c79410ae
# This is a bad url
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='ec2-50-16-164-129.compute-1.amazonaws.com', port=443): Max retries exceeded with url: /ags/services/ExecuteQuery/MapServer/WMSServer (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B2FDBB780>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = tquink
# Folder = DemoIntelligence
# Item = Execute Query
# Type = WMS
# URL = https://ec2-50-16-164-129.compute-1.amazonaws.com/ags/services/ExecuteQuery/MapServer/WMSServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=d0e29e815fc7439580f140feb2ef393a
# This is a bad url
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='ec2-50-16-164-129.compute-1.amazonaws.com', port=443): Max retries exceeded with url: /ags/rest/services/ExecuteQuery/MapServer (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B2FDD2E80>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = tquink
# Folder = DemoIntelligence
# Item = Execute Query for ArcGIS Predictive Analysis
# Type = Map Service
# URL = https://ec2-50-16-164-129.compute-1.amazonaws.com/ags/rest/services/ExecuteQuery/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=d46a3983261b4d2288e7b350984588a1
# This is a bad url
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='ec2-50-16-164-129.compute-1.amazonaws.com', port=443): Max retries exceeded with url: /ags/rest/services/ExecuteQuery/GPServer (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B2FDC9860>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = tquink
# Folder = DemoIntelligence
# Item = Execute Query GP Service
# Type = Geoprocessing Service
# URL = https://ec2-50-16-164-129.compute-1.amazonaws.com/ags/rest/services/ExecuteQuery/GPServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=1667f178d4794b82bf04ca6a75cdc16f
# This is a bad url
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='ec2-50-16-164-129.compute-1.amazonaws.com', port=443): Max retries exceeded with url: /SolutionsWeb/Apps/NationalIntel/ImageDiscovery/ (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B2FDB1048>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = tquink
# Folder = DemoIntelligence
# Item = Image Discovery
# Type = Web Mapping Application
# URL = https://ec2-50-16-164-129.compute-1.amazonaws.com/SolutionsWeb/Apps/NationalIntel/ImageDiscovery/
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=72848e805c3c4935a2951e38576dab3d
# This is a bad url
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='ec2-50-16-164-129.compute-1.amazonaws.com', port=443): Max retries exceeded with url: /SolutionsWeb/Apps/NationalIntel/ImageObservables/ (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B30F683C8>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = tquink
# Folder = DemoIntelligence
# Item = Image Observables
# Type = Web Mapping Application
# URL = https://ec2-50-16-164-129.compute-1.amazonaws.com/SolutionsWeb/Apps/NationalIntel/ImageObservables/
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=c0d8dd406e3a4d9ba9992dcc0417cd9c
# This is a bad url
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='ec2-50-16-164-129.compute-1.amazonaws.com', port=443): Max retries exceeded with url: /ags/rest/services/NationalIntelligence/MovementAnalysis/MapServer (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B30F68E10>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = tquink
# Folder = DemoIntelligence
# Item = Movement Analysis
# Type = Map Service
# URL = https://ec2-50-16-164-129.compute-1.amazonaws.com/ags/rest/services/NationalIntelligence/MovementAnalysis/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=aa5c160f299c48bd97d96eafd52fdd2b
# This is a bad url
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='ec2-50-16-164-129.compute-1.amazonaws.com', port=443): Max retries exceeded with url: /ags/rest/services/NationalIntelligence/MovementAnalysis/FeatureServer (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B2FDB1978>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = tquink
# Folder = DemoIntelligence
# Item = Movement Analysis
# Type = Feature Service
# URL = https://ec2-50-16-164-129.compute-1.amazonaws.com/ags/rest/services/NationalIntelligence/MovementAnalysis/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=c0b7527eca9146ca8b0fcd2abcc9269c
# This is a bad url
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='ec2-50-16-164-129.compute-1.amazonaws.com', port=443): Max retries exceeded with url: /ags/rest/services/NationalIntelligence/NAIP/ImageServer (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B2FDB10B8>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = tquink
# Folder = DemoIntelligence
# Item = NAIP
# Type = Image Service
# URL = https://ec2-50-16-164-129.compute-1.amazonaws.com/ags/rest/services/NationalIntelligence/NAIP/ImageServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=605f3bac99da4a97aef269cd61cf7233
# This is a bad url
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='ec2-50-16-164-129.compute-1.amazonaws.com', port=443): Max retries exceeded with url: /ags/rest/services/NationalIntelligence/ObservationReportsML/MapServer (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B2FDC5588>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = tquink
# Folder = DemoIntelligence
# Item = Observation Reports for MarkLogic
# Type = Map Service
# URL = https://ec2-50-16-164-129.compute-1.amazonaws.com/ags/rest/services/NationalIntelligence/ObservationReportsML/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=309d8c2c23b24fca917794a292e9fa35
# This is a bad url
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='ec2-50-16-164-129.compute-1.amazonaws.com', port=443): Max retries exceeded with url: /ags/rest/services/NationalIntelligence/OptimizedHotSpot/GPServer (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B2FDD2D30>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = tquink
# Folder = DemoIntelligence
# Item = Optimized Hot Spot Tool
# Type = Geoprocessing Service
# URL = https://ec2-50-16-164-129.compute-1.amazonaws.com/ags/rest/services/NationalIntelligence/OptimizedHotSpot/GPServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=95880bdd7096463c9fee6a3cd91d5a1e
# This is a bad url
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='ec2-50-16-164-129.compute-1.amazonaws.com', port=443): Max retries exceeded with url: /ags/rest/services/NationalIntelligence/ObservationReportsML/FeatureServer (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B2FDA2080>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = tquink
# Folder = DemoIntelligence
# Item = Observation Reports for MarkLogic
# Type = Feature Service
# URL = https://ec2-50-16-164-129.compute-1.amazonaws.com/ags/rest/services/NationalIntelligence/ObservationReportsML/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=711057c71fe14483ad9c4b3bc4b5e311
# This is a bad url
# -------------------------Item-------------------------------
# ...
# This is a bad url
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='ec2-50-16-164-129.compute-1.amazonaws.com', port=443): Max retries exceeded with url: /ags/rest/services/Military/WorldPortIndexWith15nmBuffer/FeatureServer (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B293CC748>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = tquink
# Folder = DemoMilitary
# Item = World Port Index with Buffer
# Type = Feature Service
# URL = https://ec2-50-16-164-129.compute-1.amazonaws.com/ags/rest/services/Military/WorldPortIndexWith15nmBuffer/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=c1c7094a99d5487a8838c82214e0386e
# This is a bad url
# -------------------------Item-------------------------------
# HTTPSConnectionPool(host='ec2-50-16-164-129.compute-1.amazonaws.com', port=443): Max retries exceeded with url: /ags/rest/services/Military/WorldPortIndexWith15nmBuffer/MapServer (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000023B2FDBB390>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# User = tquink
# Folder = DemoMilitary
# Item = World Port Index with Buffer
# Type = Map Service
# URL = https://ec2-50-16-164-129.compute-1.amazonaws.com/ags/rest/services/Military/WorldPortIndexWith15nmBuffer/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=42cb2517a7dc49bbb74e7abd4699ba48
# This is a bad url
# -------------------------Item-------------------------------
# User = tquink
# Folder = Installation
# Item = InstallationScene_WFL
# Type = Feature Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/InstallationScene_WFL/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=4ab7a35559444591995a83e164fa2c25
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = Cover
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/Cover/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=a2ca78bb86d54410b97c771782ad9adb
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = Drop Zones
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/Drop_Zone_Analysis/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=f8500c8a0984466092ffbbbcee956d04
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = Area of Operations
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/Area_Of_Operation/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=8eabf3972a7344df9fbe1bba7b569567
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = Cross-Country Movement (HMMWV)
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/HMMWV_CCM/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=13bff2f7077340209cee8456d3702ad4
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = Incident Hot Spots
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/Incident_Hot_Spots/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=e982691e8e6e4a3eada6479a0799a713
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = Hot Spots By Area
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/Hot_Spots_By_Area/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=f9e4c8b57f0343bb86b3e9fee446ad2d
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = PhotoPoints
# Type = Feature Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/PhotoPoints/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=8ec8948f9c3d4107b5d6b9b1250a07d2
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = Incident Density
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/IncidentDensity/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=16a15a642b8343f29eba8e47f9de0647
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = CommunityAddresses
# Type = Feature Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/CommunityAddresses/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=f642d2300af34b24b2e4511878ae175a
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = Installation_WFL
# Type = Feature Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/Installation_WFL/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=9b611d1d5ab14139a3a39472cb04812a
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = InstallationScene_WSL
# Type = Feature Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/InstallationScene_WSL/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=239061a3207b414aba6fd1d32e4b0826
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = InstallationScene_WSL1
# Type = Feature Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/InstallationScene_WSL1/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=ed275b4092bb4db4997d3c5b16bb48e5
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = Compound_Analysis_WTL1
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/Compound_Analysis_WTL1/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=ecd5a1aca33c4f0b93080824e45d240a
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = AirC2_ACO_ACM
# Type = Feature Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/AirC2_ACO_ACM/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=33c905082fb04729a14f45ec39ee8041
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = MCOO03_WFL1
# Type = Feature Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/MCOO03_WFL1/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=1765479681ec4b5c9d228668af1fa7a1
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = ASAM1978to2016
# Type = Feature Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/ASAM_shp/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=77016e5b33bf43ed9ea89408749f92d7
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = AirspaceControlMeans
# Type = Feature Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/AirspaceControlMeans/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=7ad6a9ac23884f48bba844cc534c0a6d
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = MilSym
# Type = Feature Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/MilSym/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=0478fb2fe1714570aabe8476c3e0c2e9
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = MCOO_Final_WFL1
# Type = Feature Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/MCOO_Final_WFL1/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=670294592c954d0d86c39849ed40e9e3
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = Installation_WTL4
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/Installation_WTL4/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=9e33a27674b642d8b9bd65acf4a5ad39
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = InstallationScene_WTL6
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/InstallationScene_WTL6/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=210d87250b1846c5bcb01618c1fa2dd1
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = Locate_Regions_Final
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/Locate_Regions_Final/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=26a97a2d56dd4ae4b5227196494db3d8
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = Installation_WTL3
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/Installation_WTL3/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=5f560ced5aa1491abb8f7551d1d0552e
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = Installation_WTL2
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/Installation_WTL2/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=0b03fef8df5d4c6ab0952f3a9ea989d1
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = InstallationScene_WTL2
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/InstallationScene_WTL2/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=c3cd525039a941c4a9ca91d3f448d665
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = Installation_WTL5
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/Installation_WTL5/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=9ffca48bbebe4ffea19ef09d492641ce
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = InstallationScene_WTL1
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/InstallationScene_WTL1/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=6804f2390f0246fa882b91b99055fccf
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = Scene3_WSL
# Type = Feature Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/Scene3_WSL/FeatureServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=c248214b98c448bd82cc9be1793e2b41
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = Installation_WTL1
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/Installation_WTL1/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=33dc794b7a874f35bb41f170229a53df
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = InstallationScene_WTL3
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/InstallationScene_WTL3/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=983d1852947840aa90d41b39ea86990a
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = InstallationScene_WTL4
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/InstallationScene_WTL4/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=2165728c683e48dc9fb5a4f8dc9e263e
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = InstallationScene_WTL5
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/InstallationScene_WTL5/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=816ce4b7001e43f8a6be681fac34ec26
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = OpsServer
# Item = Installation_WTL6
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/Hosted/Installation_WTL6/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=5115039cc48740839b4ca9df7dded4cf
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# User = tquink
# Folder = Server
# Item = SampleWorldCities
# Type = Map Service
# URL = https://wdcdefense.esri.com/server/rest/services/SampleWorldCities/MapServer
# Item URL = https://wdcdefense.esri.com/portal/home/item.html?id=54b83e851dc94082b337d90c274bb2f1
# Status Code = 200
# Server up, Service Not
# -------------------------Item-------------------------------
# Completed bad item search for tquink...
# Time taken: 11:15:47.226612
# None
# ===========================User================================
# ===========================User================================
# Collecting items for twilby...
# Completed bad item search for twilby...
# Time taken: 0:00:00.215761
# None
# ===========================User================================
# ===========================User================================
# Collecting items for VGwdcdefense...
# Completed bad item search for VGwdcdefense...
# Time taken: 0:00:01.106507
# None
# ===========================User================================
# ===========================User================================
# Collecting items for vhwdcdefense...
# Completed bad item search for vhwdcdefense...
# Time taken: 0:00:00.231282
# None
# ===========================User================================
# ===========================User================================
# Collecting items for ykkwon...
# Completed bad item search for ykkwon...
# Time taken: 0:00:01.122568
# None
# ===========================User================================
